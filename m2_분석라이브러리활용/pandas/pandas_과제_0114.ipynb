# %% [markdown]
# ### Q. titanic 데이터셋에서 age, fare 2개 열을 선택하여 데이터프레임 df를 만드세요

# %%
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset('titanic')
df = titanic.loc[:,['age','fare']]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %% [markdown]
# ### Q. 10을 더하는 함수 add_10 과 두 객체의 합 add_two_obj 함수를 정의한 후 결과값이 각각 20과 20을 출력하세요.

# %%
def add_10(a):
    a = a + 10
    return a
def add_two_obj(a,b):
    return a + b
display(add_10(10))
display(add_two_obj(10,10))
# Out:
# 20
# 20

# %% [markdown]
# ### Q. 10을 곱하는 사용자 함수와 두 객체의 나눗셈을 수행하는 사용자 함수를 정의한 후 결과값이 각각 200과 10을 출력하세요.

# %%
def mul_10(a):
    a = a * 10
    return a
def div(a,b):
    return round(a/b)
display(mul_10(20))
display(div(10,1))
# Out:
# 200
# 10

# %% [markdown]
# ### Q.df_age 에 add_10 함수를 적용해서 출력하세요.

# %%
df_age = df['age']
display(df_age.head())

a = df_age.apply(add_10)
display(a.head())

b = df.age.transform(add_10)
display(b.head())
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %% [markdown]
# ### Q. 시리즈 객체 + 숫자를 연산하는 방식으로 df.age에 10을 더한 후 sr2에 저장하고 출력하세요.

# %%
sr2 = df_age.apply(add_two_obj, b = 10)
display(sr2.head())

sr4 = df.age.transform(add_two_obj, b = 10)
display(sr3.head())
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %% [markdown]
# ### Q. 람다 함수를 활용해서 위와 같은 연산을 수행하고 결과를 sr3로 출력하세요.

# %%
sr3 = df.age.transform(lambda x : add_10 (x))
sr3
# Out:
# 0      32.0
# 1      48.0
# 2      36.0
# 3      45.0
# 4      45.0
#        ...
# 886    37.0
# 887    29.0
# 888     NaN
# 889    36.0
# 890    42.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ### Q. df의 'age', 'fare' 칼럼에 10을 더하는 사용자 함수를 정의하고 applymap()으로 각 사용자 함수를 매핑한 후 출력하세요.

# %%
import pandas as pd
import seaborn as sns

def add(a):
    a = a + 10
    return a
titanic = sns.load_dataset('titanic')
df = titanic.loc[:,['age','fare']]
display(df.head())
display(df.applymap(add).head())
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %% [markdown]
# ### Q. df_map의 [0,0]을 NaN으로 변경한 후 missing_value 함수를 적용해서 불린 시리즈를 반환하세요.

# %%
import numpy as np
def missing_value(series):
    return series.isnull()
df.iloc[0,0] = np.nan
a = df.apply(missing_value)
display(a.head(),type(a))
# Out:
#      age   fare
# 0   True  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Q. titanic 데이터셋을 seaborn에서 로딩한 후 블린 인덱싱을 이용하여 아래 사항들을 수행하세요.
# - 나이가 10대(10~19세)인 승객만 따로 선택
# - 나이가 10세 미만(0~9세)이고 여성인 승객만 따로 선택
# - 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 age, sex, alone 열만 선택

# %%
import seaborn as sns

ti = sns.load_dataset('titanic')
a = (ti.age > 9) & (ti.age < 20)
a1 = ti.loc[a,:]
display(a1)
b = (ti.age <10) & (ti.sex =='female')
b1 = ti.loc[b,:]
display(b1)
c = (ti.age < 10) | (ti.age > 59)
c1 = ti.loc[c,['age','sex','alone']]
display(c1)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 14          0       3  female  14.0      0      0    7.8542        S   Third
# 22          1       3  female  15.0      0      0    8.0292        Q   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 38          0       3  female  18.0      2      0   18.0000        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 853         1       1  female  16.0      0      1   39.4000        S   First
# 855         1       3  female  18.0      0      1    9.3500        S   Third
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 877         0       3    male  19.0      0      0    7.8958        S   Third
# 887         1       1  female  19.0      0      0   30.0000        S   First
#
# ...

# %% [markdown]
# ## Q. 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 alone 열만 선택한 후 값을 True로 변경하세요

# %%
import seaborn as sns

ti = sns.load_dataset('titanic')

a = (ti.age < 10) | (ti.age > 59)
b = ti[['alone']].replace(a,true)
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13408/2288176230.py in <module>
#       4
#       5 a = (ti.age < 10) | (ti.age > 59)
# ----> 6 b = ti[['alone']].replace(a,true)
#       7 b
#
# NameError: name 'true' is not defined

# %% [markdown]
# ### Q. 최대값 - 최소값을 반환하는 사용자 함수를 min_max로 정의하고 age, fare 열로 구성되는 타이타닉 데이터프레임df 에 적용하여 결과와 자료형을 출력하세요. source : titanic = sns.load_dataset('titanic')

# %% [markdown]
# ### Q. df 에서 'age' 칼럼과 'fare'칼럼을 더한 가격을 리턴하는 사용자 함수를 정의한 후 df['add'] 변수를 생성하여 출력하세요.(lambda 함수 사용)

# %% [markdown]
# ### Q. 'age', 'fare' 두개 칼럼으로 구성되는 titanic 데이터프레임에서 [0,1]의 값을 NaN을 변경한 후 df 이름으로 출력하세요.

# %% [markdown]
# ### Q. 각 열의 NaN 찾기, 각 열의 NaN 개수 반환, 데이터프레임의 총 NaN 개수를 반환하는 사용자 함수를 정의한 후 df.pipe 메소드로 함수 매핑한 결과를 모두 출력하세요.

# %% [markdown]
# ### Q. 타이타닉 df의 열 순서를 아래와 같이 재구성하고 출력하세요
# * 열 선택 : ['pclass', 'sex', 'age', 'survived'].
# * 열 이름의 리스트 만들기
# * 열 이름을 알파벳 순으로 정렬하기
# * 열 이름을 기존 순서의 정반대 역순으로 정렬하기
# * 열 이름을 사용자가 정의한 임의의 순서로 재배치하기
